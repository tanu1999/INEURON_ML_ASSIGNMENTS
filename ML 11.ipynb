# %% [markdown]
# 1. Given X be a discrete random variable with the following PMF

# %% [markdown]
# ![1.png](attachment:b350d714-9de3-44e1-b457-e448e57a154b.png)

# %% [markdown]
# Find the range RX of the random variable X.
#
# Find P(X ≤ 0.5)
#
# Find P(0.25
#
# P(X = 0.2|X<0.6

# %% [markdown]
# ![image.png](attachment:7842ad9f-df8b-473c-8499-02077f245b7c.png)

# %% [markdown]
# 2.Two equal and fair dice are rolled, and we observed two numbers X and Y.
#
# Find RX, RY, and the PMFs of X and Y.
#
# Find P(X = 2,Y = 6).
#
# Find P(X>3|Y = 2).
#
# If Z = X + Y. Find the range and PMF of Z.
#
# Find P(X = 4|Z = 8).

# %% [markdown]
# ![image.png](attachment:8ce5ecba-b638-4b94-ace0-45b057e229a2.png)

# %% [markdown]
# ![image.png](attachment:49cd6b01-bf33-461d-8f3a-edf9ab2cd7c2.png)

# %% [markdown]
# 3. In an exam, there were 20 multiple-choice questions. Each question had 44 possible options. A student knew the answer to 10 questions, but the other 10 questions were unknown to him, and he chose answers randomly. If the student X's score is equal to the total number of correct answers, then find out the PMF of X. What is P(X>15)?

# %% [markdown]
# ![image.png](attachment:1d0a368f-dd38-4e61-8404-000892808ec3.png)

# %% [markdown]
# 4. The number of students arriving at a college between a time interval is a Poisson random variable. On average, 10 students arrive per hour. Let Y be the number of students arriving from 10 am to 11:30 am. What is P(10¶

# %% [markdown]
# ![image.png](attachment:49c65080-5c32-4fc8-b12f-8e3a619a55d1.png)

# %% [markdown]
# 5.Two independent random variables, X and Y,are given such that X~Poisson(α) and Y~Poisson(β). State a new random variable as Z = X + Y. Find out the PMF of Z.

# %% [markdown]
# ![image.png](attachment:2b0e5edf-ee17-49e7-89d6-e80a320ef578.png)

# %% [markdown]
# 6. There is a discrete random variable X with the pmf.

# %% [markdown]
# ![image.png](attachment:17aa06e4-eac1-4879-92d5-02c19b0a3084.png)

# %% [markdown]
#  If we define a new random variable Y = (X + 1)2 then
#
# Find the range of Y.
#
# Find the pmf of Y.

# %% [markdown]
# 2.Assuming X is a continuous random variable with PDF

# %% [markdown]
# ![image.png](attachment:1793ba7c-062b-4fc0-8c4b-530afa34c37f.png)

# %% [markdown]
# Find EX and Var(X).
#
# Find P(X ≥ 1/2).
#
# If X is a continuous random variable with pdf

# %% [markdown]
# ![image.png](attachment:d6bb2fa2-4393-406c-8835-eb92a8b29f49.png)

# %% [markdown]
# ![image.png](attachment:f98e22e5-e53b-452c-9c89-1aa44e9116fd.png)

# %% [markdown]
#  If X~Uniform and Y = sin(X), then find fY(y). 4. If X is a random variable with CDF image-4.png
#
# What kind of random variable is X: discrete, continuous, or mixed?
#
# Find the PDF of X, fX(x).
#
# Find E(eX).
#
# Find P(X = 0|X≤0.5).

# %% [markdown]
# 5. There are two random variables X and Y with joint PMF given in Table below
#
# Find P(X≤2, Y≤4).
#
# Find the marginal PMFs of X and Y.
#
# Find P(Y = 2|X = 1).
#
# Are X and Y independent?

# %% [markdown]
# ![image.png](attachment:cb4ba561-cc2f-40e7-879d-5b511604d8e4.png)

# %% [markdown]
# 7.If A and B are two jointly continuous random variables with joint PDF

# %% [markdown]
# ![image.png](attachment:df8a8b5a-c068-428d-bd62-9b0024746111.png)

# %% [markdown]
# Find fX(a) and fY(b).
#
# Are A and B independent of each other?
#
# Find the conditional PDF of A given B = b, fA|B(a|b).
#
# Find E[A|B = b], for 0 ≤ y ≤ 1.
#
# Find Var(A|B = b), for 0 ≤ y ≤ 1.

# %% [markdown]
# ![image.png](attachment:ff55a06c-9a5c-45c5-834b-87948f813237.png)|

# %% [markdown]
# ![image.png](attachment:7bfcf0df-a365-474e-9b88-a6ae107def93.png)

# %% [markdown]
# 8.There are 100 men on a ship. If Xi is the ith man's weight on the ship and Xi's are independent and identically distributed and EXi = μ = 170 and σXi = σ = 30. Find the probability that the men's total weight on the ship exceeds 18,000.

# %% [markdown]
# ![image.png](attachment:84cdcc0e-cd24-43a8-9d0e-444d64d390d7.png)

# %% [markdown]
# 9.Let X1, X2, ……, X25 are independent and identically distributed. And have the following PMF. If Y = X1 + X2 + … + Xn, estimate P(4 ≤ Y ≤ 6) using central limit theorem.
#
# 0.2405
